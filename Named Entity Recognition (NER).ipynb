# %%
# !pip install spacy
#import spacy

# 1. Load the pre-trained NLP model
nlp = spacy.load("en_core_web_sm")

# 2. Pass your text through the NLP pipeline
text = "Apple bought a startup in London for $1 billion in 2024."
doc = nlp(text)

# 3. Extract and print entities
print("TEXT".ljust(15), "LABEL")
print("-" * 25)
for ent in doc.ents:
    print(ent.text.ljust(15), ent.label_)
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.1.2 is available.
# You should consider upgrading via the 'C:\Users\LENOVO\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       1 get_ipython().system('pip install spacy')
#       2 #import spacy
#       3
#       4 # 1. Load the pre-trained NLP model
# ----> 5 nlp = spacy.load("en_core_web_sm")
#       7 # 2. Pass your text through the NLP pipeline
#       8 text = "Apple bought a startup in London for $1 billion in 2024."
#
# NameError: name 'spacy' is not defined

# %%
import sys
import subprocess

# 1. Install spaCy into your active environment
subprocess.check_call([sys.executable, "-m", "pip", "install", "spacy"])

# 2. Download the model into your active environment
subprocess.check_call([sys.executable, "-m", "spacy", "download", "en_core_web_sm"])

# 3. Test the load
import spacy
nlp = spacy.load("en_core_web_sm")
print("Successfully loaded!")
# Out:
# Successfully loaded!
