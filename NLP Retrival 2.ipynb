# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

# 1. SAMPLE CORPUS 
corpus = [
    "Python is a popular programming language for data science and machine learning.",
    "The golden retriever is a friendly dog breed known for being intelligent and loyal.",
    "Natural Language Processing helps computers understand and process human speech.",
    "Neural networks and transformers power modern artificial intelligence models.",
    "French Bulldogs are small, muscular dogs with cute bat-like ears."
]


class TFIDFRetriever:
    def __init__(self, corpus):
        self.corpus = corpus
        self.vectorizer = TfidfVectorizer(stop_words='english')
        # Fits and transforms corpus into sparse vectors
        self.doc_vectors = self.vectorizer.fit_transform(corpus)

    def search(self, query, top_k=2):
        # Convert query to vector
        query_vector = self.vectorizer.transform([query])
        # Compute cosine similarity between query and all documents
        similarities = cosine_similarity(query_vector, self.doc_vectors).flatten()
        # Sort indices by highest similarity
        top_indices = np.argsort(similarities)[::-1][:top_k]
        
        results = []
        for idx in top_indices:
            results.append((self.corpus[idx], float(similarities[idx])))
        return results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 36
#      34         return results
#      35 tfidf_system = TFIDFRetriever(corpus)
# ---> 36 dense_system = DenseRetriever(corpus)
#      38 # Query with synonyms / semantic meaning ("canine" is not in the text, but "dog" is)
#      39 query = "What are some good canine pets?"
#
# NameError: name 'DenseRetriever' is not defined
